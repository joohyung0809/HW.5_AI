# %%
# -*- coding: utf-8 -*-

from sklearn.datasets import fetch_openml
mnist = fetch_openml('mnist_784', version=1, cache=True)
X = mnist.data
y = mnist.target

import matplotlib.pyplot as plt
import torch
from torch.utils.data import TensorDataset, DataLoader
from sklearn.model_selection import train_test_split

# %%
import torch
from torch.utils.data import TensorDataset, DataLoader
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=1/7, random_state=0)
X_train = torch.Tensor(X_train.values)
X_test = torch.Tensor(X_test.values)
y_train = torch.LongTensor(list(map(int, y_train)))
y_test = torch.LongTensor(list(map(int, y_test)))

import torch.nn as nn
import torch.nn.functional as F
from torch import optim
from torch.autograd import Variable

X_train = X_train.view(-1, 1,28,28).float()
X_test = X_test.view(-1, 1,28,28).float()
print(X_train.shape)
print(X_test.shape)

train = TensorDataset(X_train, y_train)
test = TensorDataset(X_test, y_test)
BATCH_SIZE = 32
loader_train = DataLoader(train, batch_size=BATCH_SIZE, shuffle = False)
loader_test = DataLoader(test, batch_size=BATCH_SIZE, shuffle = False)



class CNN(nn.Module):
    def __init__(self):
        
        super(CNN, self).__init__()
        self.conv1 = nn.Conv2d(1, 32, kernel_size=5)
        self.conv2 = nn.Conv2d(32, 32, kernel_size=5)
        self.conv3 = nn.Conv2d(32, 64, kernel_size=5)
        self.fc1 = nn.Linear(3*3*64, 256)
        self.fc2 = nn.Linear(256, 10)
        
        self.loss_fn = nn.CrossEntropyLoss()
        self.optimizer = optim.Adam(self.parameters(), lr = 0.01)
        
    def forward(self, x):
       x = F.relu(self.conv1(x))
       x = F.relu(F.max_pool2d(self.conv2(x), 2))
       x = F.dropout(x, p =0.5, training=self.training)
       x = F.relu(F.max_pool2d(self.conv3(x),2))
       x = F.dropout(x, p=0.5, training=self.training)
       x = x.view(-1,3*3*64 )
       x = F.relu(self.fc1(x))
       x = F.dropout(x, training=self.training)
       x = self.fc2(x)
       return F.log_softmax(x, dim=1)
       
##torch.nn.Conv2d(in_channels, out_channels, kernel_size, stride=1, padding=0, dilation=1, groups=1, bias=True, padding_mode='zeros')

def fit(model, loder_train):
    optimizer = torch.optim.Adam(model.parameters())
    error = nn.CrossEntropyLoss()
    EPOCHS = 1
    model.train()
    for epoch in range(EPOCHS):
        correct = 0
        for batch_idx, (X_batch, y_batch) in enumerate(loader_train):
            var_X_batch = Variable(X_batch).float()
            var_y_batch = Variable(y_batch)
            optimizer.zero_grad()
            output = model(var_X_batch)
            loss = error(output, var_y_batch)
            loss.backward()
            optimizer.step()
            predicted = torch.max(output.data, 1)[1]
            correct += (predicted == var_y_batch).sum()
            if batch_idx & 50 == 0:
                print('에포크 : {}[{}/{} ({:.0f}%)]\t 손실함수 : {:.6f}\t Accuracy:{:.3f}%'.format(
                epoch, batch_idx*len(X_batch), len(loader_train),100.*batch_idx/len(loader_train),loss.data, correct*100./ (BATCH_SIZE*(batch_idx+1))))      
    
def evaluate(model):
    correct = 0 
    for test_imgs, test_labels in loader_test:
        test_imgs = Variable(test_imgs).float()
        output = model(test_imgs)
        predicted = torch.max(output,1)[1]
        correct += (predicted == test_labels).sum()
        print("테스트 데이터 정확도: {:.3f}% ".format( float(correct) / (len(loader_test)*BATCH_SIZE)))
            
            
cnn = CNN()
evaluate(cnn)
fit(cnn, loader_train)
cnn.eval()
evaluate(cnn)
index = 10
data = X_test[index].view(-1, 1,28,28).float()
output = cnn(data)
print('{} 번째 학습데이터의 테스트 결과 : {}'.format(index, output))
_, predicted = torch.max(output, 1)  
print('{}번째 데이터의 예측 {}'.format(index, predicted.numpy()))
print('실제 레이블 : {}'.format(y_test[index]))
# Out:
# torch.Size([60000, 1, 28, 28])
# torch.Size([10000, 1, 28, 28])
# 테스트 데이터 정확도: 0.000%
# 테스트 데이터 정확도: 0.001%
# 테스트 데이터 정확도: 0.001%
# 테스트 데이터 정확도: 0.001%
# 테스트 데이터 정확도: 0.002%
# 테스트 데이터 정확도: 0.002%
# 테스트 데이터 정확도: 0.003%
# 테스트 데이터 정확도: 0.003%
# 테스트 데이터 정확도: 0.003%
# 테스트 데이터 정확도: 0.004%
# 테스트 데이터 정확도: 0.004%
# 테스트 데이터 정확도: 0.004%
# 테스트 데이터 정확도: 0.004%
# 테스트 데이터 정확도: 0.005%
# 테스트 데이터 정확도: 0.005%
# 테스트 데이터 정확도: 0.005%
# 테스트 데이터 정확도: 0.006%
# 테스트 데이터 정확도: 0.007%
# 테스트 데이터 정확도: 0.007%
# 테스트 데이터 정확도: 0.007%
# 테스트 데이터 정확도: 0.007%
# 테스트 데이터 정확도: 0.008%
# 테스트 데이터 정확도: 0.008%
# 테스트 데이터 정확도: 0.009%
# 테스트 데이터 정확도: 0.009%
# 테스트 데이터 정확도: 0.010%
# 테스트 데이터 정확도: 0.010%
# 테스트 데이터 정확도: 0.011%
# 테스트 데이터 정확도: 0.011%
# 테스트 데이터 정확도: 0.011%
# 테스트 데이터 정확도: 0.011%
# 테스트 데이터 정확도: 0.011%
# 테스트 데이터 정확도: 0.012%
# 테스트 데이터 정확도: 0.012%
# 테스트 데이터 정확도: 0.012%
# 테스트 데이터 정확도: 0.013%
# 테스트 데이터 정확도: 0.013%
# 테스트 데이터 정확도: 0.014%
# 테스트 데이터 정확도: 0.014%
# 테스트 데이터 정확도: 0.014%
# 테스트 데이터 정확도: 0.015%
# 테스트 데이터 정확도: 0.015%
# 테스트 데이터 정확도: 0.016%
# 테스트 데이터 정확도: 0.016%
# 테스트 데이터 정확도: 0.017%
# 테스트 데이터 정확도: 0.017%
# 테스트 데이터 정확도: 0.017%
# 테스트 데이터 정확도: 0.017%
# 테스트 데이터 정확도: 0.018%
# 테스트 데이터 정확도: 0.018%
# 테스트 데이터 정확도: 0.018%
# 테스트 데이터 정확도: 0.019%
# 테스트 데이터 정확도: 0.019%
# 테스트 데이터 정확도: 0.020%
# 테스트 데이터 정확도: 0.020%
# 테스트 데이터 정확도: 0.021%
# 테스트 데이터 정확도: 0.021%
# 테스트 데이터 정확도: 0.021%
# 테스트 데이터 정확도: 0.021%
# 테스트 데이터 정확도: 0.022%
# 테스트 데이터 정확도: 0.022%
# 테스트 데이터 정확도: 0.022%
# 테스트 데이터 정확도: 0.023%
# 테스트 데이터 정확도: 0.023%
# 테스트 데이터 정확도: 0.023%
# 테스트 데이터 정확도: 0.023%
# 테스트 데이터 정확도: 0.024%
# 테스트 데이터 정확도: 0.024%
# 테스트 데이터 정확도: 0.024%
# 테스트 데이터 정확도: 0.024%
# 테스트 데이터 정확도: 0.025%
# 테스트 데이터 정확도: 0.025%
# 테스트 데이터 정확도: 0.025%
# 테스트 데이터 정확도: 0.026%
# 테스트 데이터 정확도: 0.026%
# 테스트 데이터 정확도: 0.026%
# 테스트 데이터 정확도: 0.027%
# 테스트 데이터 정확도: 0.027%
# 테스트 데이터 정확도: 0.027%
# 테스트 데이터 정확도: 0.028%
# 테스트 데이터 정확도: 0.028%
# 테스트 데이터 정확도: 0.028%
# 테스트 데이터 정확도: 0.029%
# 테스트 데이터 정확도: 0.029%
# 테스트 데이터 정확도: 0.029%
# 테스트 데이터 정확도: 0.030%
# 테스트 데이터 정확도: 0.030%
# 테스트 데이터 정확도: 0.031%
# 테스트 데이터 정확도: 0.031%
# 테스트 데이터 정확도: 0.031%
# 테스트 데이터 정확도: 0.032%
# 테스트 데이터 정확도: 0.032%
# 테스트 데이터 정확도: 0.032%
# 테스트 데이터 정확도: 0.033%
# 테스트 데이터 정확도: 0.033%
# 테스트 데이터 정확도: 0.034%
# 테스트 데이터 정확도: 0.034%
# 테스트 데이터 정확도: 0.034%
# 테스트 데이터 정확도: 0.034%
# 테스트 데이터 정확도: 0.035%
# 테스트 데이터 정확도: 0.035%
# 테스트 데이터 정확도: 0.035%
# 테스트 데이터 정확도: 0.036%
# 테스트 데이터 정확도: 0.036%
# 테스트 데이터 정확도: 0.037%
# 테스트 데이터 정확도: 0.037%
# 테스트 데이터 정확도: 0.037%
# 테스트 데이터 정확도: 0.038%
# 테스트 데이터 정확도: 0.038%
# 테스트 데이터 정확도: 0.038%
# 테스트 데이터 정확도: 0.039%
# 테스트 데이터 정확도: 0.039%
# 테스트 데이터 정확도: 0.039%
# 테스트 데이터 정확도: 0.039%
# 테스트 데이터 정확도: 0.039%
# 테스트 데이터 정확도: 0.040%
# 테스트 데이터 정확도: 0.040%
# 테스트 데이터 정확도: 0.041%
# 테스트 데이터 정확도: 0.041%
# 테스트 데이터 정확도: 0.042%
# 테스트 데이터 정확도: 0.042%
# 테스트 데이터 정확도: 0.042%
# 테스트 데이터 정확도: 0.043%
# 테스트 데이터 정확도: 0.043%
# 테스트 데이터 정확도: 0.043%
# 테스트 데이터 정확도: 0.044%
# 테스트 데이터 정확도: 0.044%
# 테스트 데이터 정확도: 0.044%
# 테스트 데이터 정확도: 0.045%
# 테스트 데이터 정확도: 0.045%
# 테스트 데이터 정확도: 0.045%
# 테스트 데이터 정확도: 0.046%
# 테스트 데이터 정확도: 0.046%
# 테스트 데이터 정확도: 0.046%
# 테스트 데이터 정확도: 0.047%
# 테스트 데이터 정확도: 0.047%
# 테스트 데이터 정확도: 0.048%
# 테스트 데이터 정확도: 0.048%
# 테스트 데이터 정확도: 0.049%
# 테스트 데이터 정확도: 0.049%
# 테스트 데이터 정확도: 0.049%
# 테스트 데이터 정확도: 0.049%
# 테스트 데이터 정확도: 0.050%
# 테스트 데이터 정확도: 0.050%
# 테스트 데이터 정확도: 0.050%
# 테스트 데이터 정확도: 0.051%
# 테스트 데이터 정확도: 0.051%
# 테스트 데이터 정확도: 0.051%
# 테스트 데이터 정확도: 0.052%
# 테스트 데이터 정확도: 0.052%
# 테스트 데이터 정확도: 0.053%
# 테스트 데이터 정확도: 0.053%
# 테스트 데이터 정확도: 0.053%
# 테스트 데이터 정확도: 0.054%
# 테스트 데이터 정확도: 0.054%
# 테스트 데이터 정확도: 0.054%
# 테스트 데이터 정확도: 0.054%
# 테스트 데이터 정확도: 0.055%
# 테스트 데이터 정확도: 0.055%
# 테스트 데이터 정확도: 0.056%
# 테스트 데이터 정확도: 0.056%
# 테스트 데이터 정확도: 0.056%
# 테스트 데이터 정확도: 0.057%
# 테스트 데이터 정확도: 0.057%
# 테스트 데이터 정확도: 0.057%
# 테스트 데이터 정확도: 0.057%
# 테스트 데이터 정확도: 0.058%
# 테스트 데이터 정확도: 0.058%
# 테스트 데이터 정확도: 0.058%
# 테스트 데이터 정확도: 0.059%
# 테스트 데이터 정확도: 0.059%
# 테스트 데이터 정확도: 0.059%
# 테스트 데이터 정확도: 0.059%
# 테스트 데이터 정확도: 0.060%
# 테스트 데이터 정확도: 0.060%
# 테스트 데이터 정확도: 0.060%
# 테스트 데이터 정확도: 0.060%
# 테스트 데이터 정확도: 0.061%
# 테스트 데이터 정확도: 0.061%
# 테스트 데이터 정확도: 0.062%
# 테스트 데이터 정확도: 0.062%
# 테스트 데이터 정확도: 0.062%
# 테스트 데이터 정확도: 0.062%
# 테스트 데이터 정확도: 0.063%
# 테스트 데이터 정확도: 0.063%
# 테스트 데이터 정확도: 0.063%
# 테스트 데이터 정확도: 0.064%
# 테스트 데이터 정확도: 0.064%
# 테스트 데이터 정확도: 0.064%
# 테스트 데이터 정확도: 0.065%
# 테스트 데이터 정확도: 0.065%
# 테스트 데이터 정확도: 0.065%
# 테스트 데이터 정확도: 0.065%
# 테스트 데이터 정확도: 0.066%
# 테스트 데이터 정확도: 0.066%
# 테스트 데이터 정확도: 0.067%
# 테스트 데이터 정확도: 0.067%
# 테스트 데이터 정확도: 0.068%
# 테스트 데이터 정확도: 0.068%
# 테스트 데이터 정확도: 0.068%
# 테스트 데이터 정확도: 0.069%
# 테스트 데이터 정확도: 0.069%
# 테스트 데이터 정확도: 0.069%
# 테스트 데이터 정확도: 0.069%
# 테스트 데이터 정확도: 0.070%
# 테스트 데이터 정확도: 0.070%
# 테스트 데이터 정확도: 0.070%
# 테스트 데이터 정확도: 0.070%
# 테스트 데이터 정확도: 0.071%
# 테스트 데이터 정확도: 0.071%
# 테스트 데이터 정확도: 0.072%
# 테스트 데이터 정확도: 0.072%
# 테스트 데이터 정확도: 0.073%
# 테스트 데이터 정확도: 0.073%
# 테스트 데이터 정확도: 0.074%
# 테스트 데이터 정확도: 0.074%
# 테스트 데이터 정확도: 0.074%
# 테스트 데이터 정확도: 0.074%
# 테스트 데이터 정확도: 0.075%
# 테스트 데이터 정확도: 0.075%
# 테스트 데이터 정확도: 0.075%
# 테스트 데이터 정확도: 0.076%
# 테스트 데이터 정확도: 0.076%
# 테스트 데이터 정확도: 0.077%
# 테스트 데이터 정확도: 0.077%
# 테스트 데이터 정확도: 0.078%
# 테스트 데이터 정확도: 0.078%
# 테스트 데이터 정확도: 0.079%
# 테스트 데이터 정확도: 0.079%
# 테스트 데이터 정확도: 0.079%
# 테스트 데이터 정확도: 0.080%
# 테스트 데이터 정확도: 0.080%
# 테스트 데이터 정확도: 0.080%
# 테스트 데이터 정확도: 0.080%
# 테스트 데이터 정확도: 0.080%
# 테스트 데이터 정확도: 0.080%
# 테스트 데이터 정확도: 0.081%
# 테스트 데이터 정확도: 0.081%
# 테스트 데이터 정확도: 0.081%
# 테스트 데이터 정확도: 0.081%
# 테스트 데이터 정확도: 0.081%
# 테스트 데이터 정확도: 0.082%
# 테스트 데이터 정확도: 0.082%
# 테스트 데이터 정확도: 0.083%
# 테스트 데이터 정확도: 0.083%
# 테스트 데이터 정확도: 0.083%
# 테스트 데이터 정확도: 0.084%
# 테스트 데이터 정확도: 0.084%
# 테스트 데이터 정확도: 0.085%
# 테스트 데이터 정확도: 0.085%
# 테스트 데이터 정확도: 0.085%
# 테스트 데이터 정확도: 0.085%
# 테스트 데이터 정확도: 0.085%
# 테스트 데이터 정확도: 0.086%
# 테스트 데이터 정확도: 0.086%
# 테스트 데이터 정확도: 0.087%
# 테스트 데이터 정확도: 0.087%
# 테스트 데이터 정확도: 0.088%
# 테스트 데이터 정확도: 0.088%
# 테스트 데이터 정확도: 0.088%
# 테스트 데이터 정확도: 0.088%
# 테스트 데이터 정확도: 0.089%
# 테스트 데이터 정확도: 0.089%
# 테스트 데이터 정확도: 0.089%
# 테스트 데이터 정확도: 0.090%
# 테스트 데이터 정확도: 0.090%
# 테스트 데이터 정확도: 0.090%
# 테스트 데이터 정확도: 0.090%
# 테스트 데이터 정확도: 0.091%
# 테스트 데이터 정확도: 0.091%
# 테스트 데이터 정확도: 0.091%
# 테스트 데이터 정확도: 0.091%
# 테스트 데이터 정확도: 0.092%
# 테스트 데이터 정확도: 0.092%
# 테스트 데이터 정확도: 0.093%
# 테스트 데이터 정확도: 0.093%
# 테스트 데이터 정확도: 0.094%
# 테스트 데이터 정확도: 0.095%
# 테스트 데이터 정확도: 0.095%
# 테스트 데이터 정확도: 0.095%
# 테스트 데이터 정확도: 0.096%
# 테스트 데이터 정확도: 0.096%
# 테스트 데이터 정확도: 0.096%
# 테스트 데이터 정확도: 0.097%
# 테스트 데이터 정확도: 0.097%
# 테스트 데이터 정확도: 0.097%
# 테스트 데이터 정확도: 0.097%
# 테스트 데이터 정확도: 0.097%
# 테스트 데이터 정확도: 0.098%
# 테스트 데이터 정확도: 0.098%
# 테스트 데이터 정확도: 0.099%
# 테스트 데이터 정확도: 0.099%
# 테스트 데이터 정확도: 0.099%
# 테스트 데이터 정확도: 0.100%
# 테스트 데이터 정확도: 0.100%
# 테스트 데이터 정확도: 0.101%
# 테스트 데이터 정확도: 0.101%
# 테스트 데이터 정확도: 0.101%
# 테스트 데이터 정확도: 0.102%
# 테스트 데이터 정확도: 0.102%
# 테스트 데이터 정확도: 0.103%
# 테스트 데이터 정확도: 0.103%
# 테스트 데이터 정확도: 0.104%
# 테스트 데이터 정확도: 0.104%
# 테스트 데이터 정확도: 0.104%
# 테스트 데이터 정확도: 0.104%
# 테스트 데이터 정확도: 0.104%
# 테스트 데이터 정확도: 0.105%
# 테스트 데이터 정확도: 0.105%
# 테스트 데이터 정확도: 0.105%
# 테스트 데이터 정확도: 0.106%
# 테스트 데이터 정확도: 0.106%
# 테스트 데이터 정확도: 0.106%
# 에포크 : 0[0/1875 (0%)]	 손실함수 : 32.331665	 Accuracy:6.250%
# 에포크 : 0[32/1875 (0%)]	 손실함수 : 20.416702	 Accuracy:7.812%
# 에포크 : 0[128/1875 (0%)]	 손실함수 : 4.371699	 Accuracy:8.750%
# 에포크 : 0[160/1875 (0%)]	 손실함수 : 4.122141	 Accuracy:8.854%
# 에포크 : 0[256/1875 (0%)]	 손실함수 : 2.632190	 Accuracy:7.986%
# 에포크 : 0[288/1875 (0%)]	 손실함수 : 2.339495	 Accuracy:9.375%
# 에포크 : 0[384/1875 (1%)]	 손실함수 : 2.232410	 Accuracy:10.337%
# 에포크 : 0[416/1875 (1%)]	 손실함수 : 2.257747	 Accuracy:10.268%
# 에포크 : 0[2048/1875 (3%)]	 손실함수 : 1.780128	 Accuracy:25.240%
# 에포크 : 0[2080/1875 (3%)]	 손실함수 : 1.851353	 Accuracy:25.473%
# 에포크 : 0[2176/1875 (4%)]	 손실함수 : 1.792091	 Accuracy:26.223%
# 에포크 : 0[2208/1875 (4%)]	 손실함수 : 1.706818	 Accuracy:26.562%
# 에포크 : 0[2304/1875 (4%)]	 손실함수 : 1.392255	 Accuracy:27.354%
# 에포크 : 0[2336/1875 (4%)]	 손실함수 : 1.459873	 Accuracy:27.787%
# 에포크 : 0[2432/1875 (4%)]	 손실함수 : 1.313909	 Accuracy:28.977%
# 에포크 : 0[2464/1875 (4%)]	 손실함수 : 1.356880	 Accuracy:29.327%
# 에포크 : 0[4096/1875 (7%)]	 손실함수 : 0.888916	 Accuracy:42.054%
# 에포크 : 0[4128/1875 (7%)]	 손실함수 : 0.560672	 Accuracy:42.428%
# 에포크 : 0[4224/1875 (7%)]	 손실함수 : 0.675440	 Accuracy:43.257%
# 에포크 : 0[4256/1875 (7%)]	 손실함수 : 0.641469	 Accuracy:43.540%
# 에포크 : 0[4352/1875 (7%)]	 손실함수 : 0.699246	 Accuracy:44.183%
# 에포크 : 0[4384/1875 (7%)]	 손실함수 : 1.238452	 Accuracy:44.271%
# 에포크 : 0[4480/1875 (7%)]	 손실함수 : 0.756457	 Accuracy:44.836%
# 에포크 : 0[4512/1875 (8%)]	 손실함수 : 1.138620	 Accuracy:44.982%
# 에포크 : 0[6144/1875 (10%)]	 손실함수 : 0.476248	 Accuracy:52.251%
# 에포크 : 0[6176/1875 (10%)]	 손실함수 : 0.622774	 Accuracy:52.416%
# 에포크 : 0[6272/1875 (10%)]	 손실함수 : 1.155318	 Accuracy:52.728%
# 에포크 : 0[6304/1875 (11%)]	 손실함수 : 1.065246	 Accuracy:52.778%
# 에포크 : 0[6400/1875 (11%)]	 손실함수 : 0.574555	 Accuracy:53.109%
# 에포크 : 0[6432/1875 (11%)]	 손실함수 : 0.623186	 Accuracy:53.233%
# 에포크 : 0[6528/1875 (11%)]	 손실함수 : 0.619086	 Accuracy:53.582%
# 에포크 : 0[6560/1875 (11%)]	 손실함수 : 1.235081	 Accuracy:53.641%
# 에포크 : 0[8192/1875 (14%)]	 손실함수 : 0.503915	 Accuracy:58.560%
# 에포크 : 0[8224/1875 (14%)]	 손실함수 : 0.418494	 Accuracy:58.660%
# 에포크 : 0[8320/1875 (14%)]	 손실함수 : 1.166644	 Accuracy:58.872%
# 에포크 : 0[8352/1875 (14%)]	 손실함수 : 0.515821	 Accuracy:58.969%
# 에포크 : 0[8448/1875 (14%)]	 손실함수 : 0.880610	 Accuracy:59.068%
# 에포크 : 0[8480/1875 (14%)]	 손실함수 : 0.512466	 Accuracy:59.175%
# 에포크 : 0[8576/1875 (14%)]	 손실함수 : 0.536155	 Accuracy:59.410%
# 에포크 : 0[8608/1875 (14%)]	 손실함수 : 0.749410	 Accuracy:59.491%
# 에포크 : 0[10240/1875 (17%)]	 손실함수 : 0.354055	 Accuracy:63.045%
# 에포크 : 0[10272/1875 (17%)]	 손실함수 : 0.472028	 Accuracy:63.082%
# 에포크 : 0[10368/1875 (17%)]	 손실함수 : 0.315299	 Accuracy:63.231%
# 에포크 : 0[10400/1875 (17%)]	 손실함수 : 0.423696	 Accuracy:63.286%
# 에포크 : 0[10496/1875 (17%)]	 손실함수 : 0.867068	 Accuracy:63.440%
# 에포크 : 0[10528/1875 (18%)]	 손실함수 : 0.537856	 Accuracy:63.504%
# 에포크 : 0[10624/1875 (18%)]	 손실함수 : 0.351441	 Accuracy:63.701%
# 에포크 : 0[10656/1875 (18%)]	 손실함수 : 0.769712	 Accuracy:63.744%
# 에포크 : 0[12288/1875 (20%)]	 손실함수 : 0.799559	 Accuracy:66.461%
# 에포크 : 0[12320/1875 (21%)]	 손실함수 : 0.406924	 Accuracy:66.524%
# 에포크 : 0[12416/1875 (21%)]	 손실함수 : 0.351411	 Accuracy:66.669%
# 에포크 : 0[12448/1875 (21%)]	 손실함수 : 0.584783	 Accuracy:66.715%
# 에포크 : 0[12544/1875 (21%)]	 손실함수 : 0.714505	 Accuracy:66.810%
# 에포크 : 0[12576/1875 (21%)]	 손실함수 : 0.222081	 Accuracy:66.870%
# 에포크 : 0[12672/1875 (21%)]	 손실함수 : 0.375795	 Accuracy:66.995%
# 에포크 : 0[12704/1875 (21%)]	 손실함수 : 0.728261	 Accuracy:67.023%
# 에포크 : 0[14336/1875 (24%)]	 손실함수 : 0.328253	 Accuracy:69.223%
# 에포크 : 0[14368/1875 (24%)]	 손실함수 : 0.392468	 Accuracy:69.257%
# 에포크 : 0[14464/1875 (24%)]	 손실함수 : 0.586593	 Accuracy:69.371%
# 에포크 : 0[14496/1875 (24%)]	 손실함수 : 0.310331	 Accuracy:69.418%
# 에포크 : 0[14592/1875 (24%)]	 손실함수 : 0.630833	 Accuracy:69.530%
# 에포크 : 0[14624/1875 (24%)]	 손실함수 : 0.500894	 Accuracy:69.576%
# 에포크 : 0[14720/1875 (25%)]	 손실함수 : 0.670565	 Accuracy:69.652%
# 에포크 : 0[14752/1875 (25%)]	 손실함수 : 0.294680	 Accuracy:69.697%
# 에포크 : 0[16384/1875 (27%)]	 손실함수 : 0.176505	 Accuracy:71.436%
# 에포크 : 0[16416/1875 (27%)]	 손실함수 : 0.736576	 Accuracy:71.455%
# 에포크 : 0[16512/1875 (28%)]	 손실함수 : 0.273749	 Accuracy:71.567%
# 에포크 : 0[16544/1875 (28%)]	 손실함수 : 0.464403	 Accuracy:71.597%
# 에포크 : 0[16640/1875 (28%)]	 손실함수 : 0.383651	 Accuracy:71.701%
# 에포크 : 0[16672/1875 (28%)]	 손실함수 : 0.212785	 Accuracy:71.743%
# 에포크 : 0[16768/1875 (28%)]	 손실함수 : 0.450004	 Accuracy:71.833%
# 에포크 : 0[16800/1875 (28%)]	 손실함수 : 0.357545	 Accuracy:71.845%
# 에포크 : 0[18432/1875 (31%)]	 손실함수 : 0.311958	 Accuracy:73.294%
# 에포크 : 0[18464/1875 (31%)]	 손실함수 : 0.267079	 Accuracy:73.324%
# 에포크 : 0[18560/1875 (31%)]	 손실함수 : 0.637173	 Accuracy:73.403%
# 에포크 : 0[18592/1875 (31%)]	 손실함수 : 0.112206	 Accuracy:73.443%
# 에포크 : 0[18688/1875 (31%)]	 손실함수 : 0.440579	 Accuracy:73.504%
# 에포크 : 0[18720/1875 (31%)]	 손실함수 : 0.158883	 Accuracy:73.539%
# 에포크 : 0[18816/1875 (31%)]	 손실함수 : 0.145112	 Accuracy:73.626%
# 에포크 : 0[18848/1875 (31%)]	 손실함수 : 0.629905	 Accuracy:73.644%
# 에포크 : 0[20480/1875 (34%)]	 손실함수 : 0.565173	 Accuracy:74.888%
# 에포크 : 0[20512/1875 (34%)]	 손실함수 : 0.282167	 Accuracy:74.922%
# 에포크 : 0[20608/1875 (34%)]	 손실함수 : 0.152058	 Accuracy:74.976%
# 에포크 : 0[20640/1875 (34%)]	 손실함수 : 0.271172	 Accuracy:75.005%
# 에포크 : 0[20736/1875 (35%)]	 손실함수 : 0.330919	 Accuracy:75.058%
# 에포크 : 0[20768/1875 (35%)]	 손실함수 : 0.256499	 Accuracy:75.087%
# 에포크 : 0[20864/1875 (35%)]	 손실함수 : 0.280443	 Accuracy:75.163%
# 에포크 : 0[20896/1875 (35%)]	 손실함수 : 0.282730	 Accuracy:75.191%
# 에포크 : 0[22528/1875 (38%)]	 손실함수 : 0.078141	 Accuracy:76.188%
# 에포크 : 0[22560/1875 (38%)]	 손실함수 : 0.613973	 Accuracy:76.186%
# 에포크 : 0[22656/1875 (38%)]	 손실함수 : 0.498846	 Accuracy:76.247%
# 에포크 : 0[22688/1875 (38%)]	 손실함수 : 0.196983	 Accuracy:76.272%
# 에포크 : 0[22784/1875 (38%)]	 손실함수 : 0.137867	 Accuracy:76.363%
# 에포크 : 0[22816/1875 (38%)]	 손실함수 : 0.432074	 Accuracy:76.383%
# 에포크 : 0[22912/1875 (38%)]	 손실함수 : 0.478779	 Accuracy:76.425%
# 에포크 : 0[22944/1875 (38%)]	 손실함수 : 0.222026	 Accuracy:76.445%
# 에포크 : 0[24576/1875 (41%)]	 손실함수 : 0.341005	 Accuracy:77.320%
# 에포크 : 0[24608/1875 (41%)]	 손실함수 : 0.035791	 Accuracy:77.350%
# 에포크 : 0[24704/1875 (41%)]	 손실함수 : 0.274741	 Accuracy:77.426%
# 에포크 : 0[24736/1875 (41%)]	 손실함수 : 0.147321	 Accuracy:77.447%
# 에포크 : 0[24832/1875 (41%)]	 손실함수 : 0.485642	 Accuracy:77.502%
# 에포크 : 0[24864/1875 (41%)]	 손실함수 : 0.359798	 Accuracy:77.518%
# 에포크 : 0[24960/1875 (42%)]	 손실함수 : 0.146074	 Accuracy:77.573%
# 에포크 : 0[24992/1875 (42%)]	 손실함수 : 0.315666	 Accuracy:77.590%
# 에포크 : 0[26624/1875 (44%)]	 손실함수 : 0.417035	 Accuracy:78.395%
# 에포크 : 0[26656/1875 (44%)]	 손실함수 : 0.123503	 Accuracy:78.417%
# 에포크 : 0[26752/1875 (45%)]	 손실함수 : 0.290117	 Accuracy:78.457%
# 에포크 : 0[26784/1875 (45%)]	 손실함수 : 0.117589	 Accuracy:78.483%
# 에포크 : 0[26880/1875 (45%)]	 손실함수 : 0.553245	 Accuracy:78.519%
# 에포크 : 0[26912/1875 (45%)]	 손실함수 : 0.189553	 Accuracy:78.537%
# 에포크 : 0[27008/1875 (45%)]	 손실함수 : 0.183139	 Accuracy:78.584%
# 에포크 : 0[27040/1875 (45%)]	 손실함수 : 0.203614	 Accuracy:78.602%
# 에포크 : 0[28672/1875 (48%)]	 손실함수 : 0.355972	 Accuracy:79.261%
# 에포크 : 0[28704/1875 (48%)]	 손실함수 : 0.254354	 Accuracy:79.280%
# 에포크 : 0[28800/1875 (48%)]	 손실함수 : 0.413929	 Accuracy:79.332%
# 에포크 : 0[28832/1875 (48%)]	 손실함수 : 0.392854	 Accuracy:79.345%
# 에포크 : 0[28928/1875 (48%)]	 손실함수 : 0.363927	 Accuracy:79.378%
# 에포크 : 0[28960/1875 (48%)]	 손실함수 : 0.347059	 Accuracy:79.394%
# 에포크 : 0[29056/1875 (48%)]	 손실함수 : 0.369108	 Accuracy:79.431%
# 에포크 : 0[29088/1875 (48%)]	 손실함수 : 0.177928	 Accuracy:79.451%
# 에포크 : 0[30720/1875 (51%)]	 손실함수 : 0.583677	 Accuracy:80.073%
# 에포크 : 0[30752/1875 (51%)]	 손실함수 : 0.353368	 Accuracy:80.081%
# 에포크 : 0[30848/1875 (51%)]	 손실함수 : 0.243965	 Accuracy:80.104%
# 에포크 : 0[30880/1875 (51%)]	 손실함수 : 0.202648	 Accuracy:80.118%
# 에포크 : 0[30976/1875 (52%)]	 손실함수 : 0.220134	 Accuracy:80.150%
# 에포크 : 0[31008/1875 (52%)]	 손실함수 : 0.189341	 Accuracy:80.161%
# 에포크 : 0[31104/1875 (52%)]	 손실함수 : 0.302398	 Accuracy:80.187%
# 에포크 : 0[31136/1875 (52%)]	 손실함수 : 0.425689	 Accuracy:80.188%
# 에포크 : 0[32768/1875 (55%)]	 손실함수 : 0.182156	 Accuracy:80.701%
# 에포크 : 0[32800/1875 (55%)]	 손실함수 : 0.125816	 Accuracy:80.714%
# 에포크 : 0[32896/1875 (55%)]	 손실함수 : 0.425746	 Accuracy:80.746%
# 에포크 : 0[32928/1875 (55%)]	 손실함수 : 0.353000	 Accuracy:80.755%
# 에포크 : 0[33024/1875 (55%)]	 손실함수 : 0.250662	 Accuracy:80.799%
# 에포크 : 0[33056/1875 (55%)]	 손실함수 : 0.359900	 Accuracy:80.806%
# 에포크 : 0[33152/1875 (55%)]	 손실함수 : 0.121770	 Accuracy:80.843%
# 에포크 : 0[33184/1875 (55%)]	 손실함수 : 0.491766	 Accuracy:80.853%
# 에포크 : 0[34816/1875 (58%)]	 손실함수 : 0.183345	 Accuracy:81.362%
# 에포크 : 0[34848/1875 (58%)]	 손실함수 : 0.584623	 Accuracy:81.365%
# 에포크 : 0[34944/1875 (58%)]	 손실함수 : 0.439254	 Accuracy:81.384%
# 에포크 : 0[34976/1875 (58%)]	 손실함수 : 0.463225	 Accuracy:81.393%
# 에포크 : 0[35072/1875 (58%)]	 손실함수 : 0.626108	 Accuracy:81.415%
# 에포크 : 0[35104/1875 (59%)]	 손실함수 : 0.094106	 Accuracy:81.429%
# 에포크 : 0[35200/1875 (59%)]	 손실함수 : 0.184539	 Accuracy:81.457%
# 에포크 : 0[35232/1875 (59%)]	 손실함수 : 0.201737	 Accuracy:81.468%
# 에포크 : 0[36864/1875 (61%)]	 손실함수 : 0.305801	 Accuracy:81.919%
# 에포크 : 0[36896/1875 (61%)]	 손실함수 : 0.335729	 Accuracy:81.924%
# 에포크 : 0[36992/1875 (62%)]	 손실함수 : 0.284056	 Accuracy:81.960%
# 에포크 : 0[37024/1875 (62%)]	 손실함수 : 0.092101	 Accuracy:81.973%
# 에포크 : 0[37120/1875 (62%)]	 손실함수 : 0.332016	 Accuracy:82.006%
# 에포크 : 0[37152/1875 (62%)]	 손실함수 : 0.497966	 Accuracy:82.014%
# 에포크 : 0[37248/1875 (62%)]	 손실함수 : 0.196966	 Accuracy:82.049%
# 에포크 : 0[37280/1875 (62%)]	 손실함수 : 0.329230	 Accuracy:82.057%
# 에포크 : 0[38912/1875 (65%)]	 손실함수 : 0.292308	 Accuracy:82.506%
# 에포크 : 0[38944/1875 (65%)]	 손실함수 : 0.284804	 Accuracy:82.512%
# 에포크 : 0[39040/1875 (65%)]	 손실함수 : 0.286288	 Accuracy:82.542%
# 에포크 : 0[39072/1875 (65%)]	 손실함수 : 0.083518	 Accuracy:82.554%
# 에포크 : 0[39168/1875 (65%)]	 손실함수 : 0.214460	 Accuracy:82.587%
# 에포크 : 0[39200/1875 (65%)]	 손실함수 : 0.177200	 Accuracy:82.596%
# 에포크 : 0[39296/1875 (65%)]	 손실함수 : 0.362638	 Accuracy:82.613%
# 에포크 : 0[39328/1875 (66%)]	 손실함수 : 0.166949	 Accuracy:82.624%
# 에포크 : 0[40960/1875 (68%)]	 손실함수 : 0.156769	 Accuracy:83.021%
# 에포크 : 0[40992/1875 (68%)]	 손실함수 : 0.255346	 Accuracy:83.029%
# 에포크 : 0[41088/1875 (68%)]	 손실함수 : 0.623882	 Accuracy:83.059%
# 에포크 : 0[41120/1875 (69%)]	 손실함수 : 0.221158	 Accuracy:83.070%
# 에포크 : 0[41216/1875 (69%)]	 손실함수 : 0.254130	 Accuracy:83.083%
# 에포크 : 0[41248/1875 (69%)]	 손실함수 : 0.336551	 Accuracy:83.086%
# 에포크 : 0[41344/1875 (69%)]	 손실함수 : 0.075615	 Accuracy:83.111%
# 에포크 : 0[41376/1875 (69%)]	 손실함수 : 0.360846	 Accuracy:83.114%
# 에포크 : 0[43008/1875 (72%)]	 손실함수 : 0.266439	 Accuracy:83.478%
# 에포크 : 0[43040/1875 (72%)]	 손실함수 : 0.165911	 Accuracy:83.488%
# 에포크 : 0[43136/1875 (72%)]	 손실함수 : 0.649302	 Accuracy:83.497%
# 에포크 : 0[43168/1875 (72%)]	 손실함수 : 0.307887	 Accuracy:83.502%
# 에포크 : 0[43264/1875 (72%)]	 손실함수 : 0.457536	 Accuracy:83.518%
# 에포크 : 0[43296/1875 (72%)]	 손실함수 : 0.216512	 Accuracy:83.526%
# 에포크 : 0[43392/1875 (72%)]	 손실함수 : 0.268115	 Accuracy:83.546%
# 에포크 : 0[43424/1875 (72%)]	 손실함수 : 0.171033	 Accuracy:83.553%
# 에포크 : 0[45056/1875 (75%)]	 손실함수 : 0.339654	 Accuracy:83.836%
# 에포크 : 0[45088/1875 (75%)]	 손실함수 : 0.277143	 Accuracy:83.843%
# 에포크 : 0[45184/1875 (75%)]	 손실함수 : 0.535241	 Accuracy:83.864%
# 에포크 : 0[45216/1875 (75%)]	 손실함수 : 0.340850	 Accuracy:83.867%
# 에포크 : 0[45312/1875 (76%)]	 손실함수 : 0.316483	 Accuracy:83.890%
# 에포크 : 0[45344/1875 (76%)]	 손실함수 : 0.127763	 Accuracy:83.897%
# 에포크 : 0[45440/1875 (76%)]	 손실함수 : 0.475713	 Accuracy:83.913%
# 에포크 : 0[45472/1875 (76%)]	 손실함수 : 0.358873	 Accuracy:83.920%
# 에포크 : 0[47104/1875 (79%)]	 손실함수 : 0.072244	 Accuracy:84.224%
# 에포크 : 0[47136/1875 (79%)]	 손실함수 : 0.320026	 Accuracy:84.231%
# 에포크 : 0[47232/1875 (79%)]	 손실함수 : 0.407731	 Accuracy:84.246%
# 에포크 : 0[47264/1875 (79%)]	 손실함수 : 0.638439	 Accuracy:84.246%
# 에포크 : 0[47360/1875 (79%)]	 손실함수 : 0.350001	 Accuracy:84.265%
# 에포크 : 0[47392/1875 (79%)]	 손실함수 : 0.194217	 Accuracy:84.272%
# 에포크 : 0[47488/1875 (79%)]	 손실함수 : 0.366088	 Accuracy:84.285%
# 에포크 : 0[47520/1875 (79%)]	 손실함수 : 0.347148	 Accuracy:84.289%
# 에포크 : 0[49152/1875 (82%)]	 손실함수 : 0.432614	 Accuracy:84.588%
# 에포크 : 0[49184/1875 (82%)]	 손실함수 : 0.232713	 Accuracy:84.596%
# 에포크 : 0[49280/1875 (82%)]	 손실함수 : 0.546405	 Accuracy:84.614%
# 에포크 : 0[49312/1875 (82%)]	 손실함수 : 0.509724	 Accuracy:84.618%
# 에포크 : 0[49408/1875 (82%)]	 손실함수 : 0.276049	 Accuracy:84.638%
# 에포크 : 0[49440/1875 (82%)]	 손실함수 : 0.461604	 Accuracy:84.638%
# 에포크 : 0[49536/1875 (83%)]	 손실함수 : 0.189749	 Accuracy:84.647%
# 에포크 : 0[49568/1875 (83%)]	 손실함수 : 0.090147	 Accuracy:84.655%
# 에포크 : 0[51200/1875 (85%)]	 손실함수 : 0.087977	 Accuracy:84.923%
# 에포크 : 0[51232/1875 (85%)]	 손실함수 : 0.198787	 Accuracy:84.927%
# 에포크 : 0[51328/1875 (86%)]	 손실함수 : 0.086368	 Accuracy:84.945%
# 에포크 : 0[51360/1875 (86%)]	 손실함수 : 0.454808	 Accuracy:84.947%
# 에포크 : 0[51456/1875 (86%)]	 손실함수 : 0.301528	 Accuracy:84.956%
# 에포크 : 0[51488/1875 (86%)]	 손실함수 : 0.265685	 Accuracy:84.961%
# 에포크 : 0[51584/1875 (86%)]	 손실함수 : 0.486119	 Accuracy:84.976%
# 에포크 : 0[51616/1875 (86%)]	 손실함수 : 0.285263	 Accuracy:84.977%
# 에포크 : 0[53248/1875 (89%)]	 손실함수 : 0.182243	 Accuracy:85.218%
# 에포크 : 0[53280/1875 (89%)]	 손실함수 : 0.011163	 Accuracy:85.227%
# 에포크 : 0[53376/1875 (89%)]	 손실함수 : 0.125895	 Accuracy:85.242%
# 에포크 : 0[53408/1875 (89%)]	 손실함수 : 0.292669	 Accuracy:85.241%
# 에포크 : 0[53504/1875 (89%)]	 손실함수 : 0.504248	 Accuracy:85.253%
# 에포크 : 0[53536/1875 (89%)]	 손실함수 : 0.448678	 Accuracy:85.256%
# 에포크 : 0[53632/1875 (89%)]	 손실함수 : 0.102211	 Accuracy:85.273%
# 에포크 : 0[53664/1875 (89%)]	 손실함수 : 0.068578	 Accuracy:85.280%
# 에포크 : 0[55296/1875 (92%)]	 손실함수 : 0.045616	 Accuracy:85.490%
# 에포크 : 0[55328/1875 (92%)]	 손실함수 : 0.186891	 Accuracy:85.495%
# 에포크 : 0[55424/1875 (92%)]	 손실함수 : 0.174539	 Accuracy:85.506%
# 에포크 : 0[55456/1875 (92%)]	 손실함수 : 0.230821	 Accuracy:85.509%
# 에포크 : 0[55552/1875 (93%)]	 손실함수 : 0.307863	 Accuracy:85.517%
# 에포크 : 0[55584/1875 (93%)]	 손실함수 : 0.122291	 Accuracy:85.524%
# 에포크 : 0[55680/1875 (93%)]	 손실함수 : 0.169554	 Accuracy:85.536%
# 에포크 : 0[55712/1875 (93%)]	 손실함수 : 0.093824	 Accuracy:85.543%
# 에포크 : 0[57344/1875 (96%)]	 손실함수 : 0.200584	 Accuracy:85.808%
# 에포크 : 0[57376/1875 (96%)]	 손실함수 : 0.165875	 Accuracy:85.812%
# 에포크 : 0[57472/1875 (96%)]	 손실함수 : 0.043047	 Accuracy:85.825%
# 에포크 : 0[57504/1875 (96%)]	 손실함수 : 0.364886	 Accuracy:85.825%
# 에포크 : 0[57600/1875 (96%)]	 손실함수 : 0.091343	 Accuracy:85.829%
# 에포크 : 0[57632/1875 (96%)]	 손실함수 : 0.078959	 Accuracy:85.835%
# 에포크 : 0[57728/1875 (96%)]	 손실함수 : 0.047590	 Accuracy:85.855%
# 에포크 : 0[57760/1875 (96%)]	 손실함수 : 0.096943	 Accuracy:85.861%
# 에포크 : 0[59392/1875 (99%)]	 손실함수 : 0.108442	 Accuracy:86.080%
# 에포크 : 0[59424/1875 (99%)]	 손실함수 : 0.245651	 Accuracy:86.084%
# 에포크 : 0[59520/1875 (99%)]	 손실함수 : 0.273907	 Accuracy:86.095%
# 에포크 : 0[59552/1875 (99%)]	 손실함수 : 0.067225	 Accuracy:86.100%
# 에포크 : 0[59648/1875 (99%)]	 손실함수 : 0.288289	 Accuracy:86.109%
# 에포크 : 0[59680/1875 (99%)]	 손실함수 : 0.074857	 Accuracy:86.115%
# 에포크 : 0[59776/1875 (100%)]	 손실함수 : 0.440537	 Accuracy:86.121%
# 에포크 : 0[59808/1875 (100%)]	 손실함수 : 0.046760	 Accuracy:86.128%
# 테스트 데이터 정확도: 0.003%
# 테스트 데이터 정확도: 0.006%
# 테스트 데이터 정확도: 0.009%
# 테스트 데이터 정확도: 0.012%
# 테스트 데이터 정확도: 0.016%
# 테스트 데이터 정확도: 0.019%
# 테스트 데이터 정확도: 0.022%
# 테스트 데이터 정확도: 0.025%
# 테스트 데이터 정확도: 0.028%
# 테스트 데이터 정확도: 0.031%
# 테스트 데이터 정확도: 0.034%
# 테스트 데이터 정확도: 0.037%
# 테스트 데이터 정확도: 0.040%
# 테스트 데이터 정확도: 0.043%
# 테스트 데이터 정확도: 0.047%
# 테스트 데이터 정확도: 0.050%
# 테스트 데이터 정확도: 0.053%
# 테스트 데이터 정확도: 0.056%
# 테스트 데이터 정확도: 0.059%
# 테스트 데이터 정확도: 0.062%
# 테스트 데이터 정확도: 0.065%
# 테스트 데이터 정확도: 0.068%
# 테스트 데이터 정확도: 0.071%
# 테스트 데이터 정확도: 0.074%
# 테스트 데이터 정확도: 0.078%
# 테스트 데이터 정확도: 0.081%
# 테스트 데이터 정확도: 0.084%
# 테스트 데이터 정확도: 0.087%
# 테스트 데이터 정확도: 0.090%
# 테스트 데이터 정확도: 0.093%
# 테스트 데이터 정확도: 0.096%
# 테스트 데이터 정확도: 0.099%
# 테스트 데이터 정확도: 0.103%
# 테스트 데이터 정확도: 0.105%
# 테스트 데이터 정확도: 0.109%
# 테스트 데이터 정확도: 0.112%
# 테스트 데이터 정확도: 0.115%
# 테스트 데이터 정확도: 0.118%
# 테스트 데이터 정확도: 0.121%
# 테스트 데이터 정확도: 0.124%
# 테스트 데이터 정확도: 0.127%
# 테스트 데이터 정확도: 0.131%
# 테스트 데이터 정확도: 0.134%
# 테스트 데이터 정확도: 0.137%
# 테스트 데이터 정확도: 0.140%
# 테스트 데이터 정확도: 0.143%
# 테스트 데이터 정확도: 0.146%
# 테스트 데이터 정확도: 0.149%
# 테스트 데이터 정확도: 0.152%
# 테스트 데이터 정확도: 0.155%
# 테스트 데이터 정확도: 0.159%
# 테스트 데이터 정확도: 0.162%
# 테스트 데이터 정확도: 0.165%
# 테스트 데이터 정확도: 0.168%
# 테스트 데이터 정확도: 0.171%
# 테스트 데이터 정확도: 0.175%
# 테스트 데이터 정확도: 0.178%
# 테스트 데이터 정확도: 0.181%
# 테스트 데이터 정확도: 0.184%
# 테스트 데이터 정확도: 0.187%
# 테스트 데이터 정확도: 0.190%
# 테스트 데이터 정확도: 0.193%
# 테스트 데이터 정확도: 0.197%
# 테스트 데이터 정확도: 0.200%
# 테스트 데이터 정확도: 0.203%
# 테스트 데이터 정확도: 0.206%
# 테스트 데이터 정확도: 0.209%
# 테스트 데이터 정확도: 0.212%
# 테스트 데이터 정확도: 0.216%
# 테스트 데이터 정확도: 0.219%
# 테스트 데이터 정확도: 0.222%
# 테스트 데이터 정확도: 0.225%
# 테스트 데이터 정확도: 0.228%
# 테스트 데이터 정확도: 0.231%
# 테스트 데이터 정확도: 0.234%
# 테스트 데이터 정확도: 0.237%
# 테스트 데이터 정확도: 0.241%
# 테스트 데이터 정확도: 0.244%
# 테스트 데이터 정확도: 0.247%
# 테스트 데이터 정확도: 0.250%
# 테스트 데이터 정확도: 0.253%
# 테스트 데이터 정확도: 0.256%
# 테스트 데이터 정확도: 0.259%
# 테스트 데이터 정확도: 0.262%
# 테스트 데이터 정확도: 0.265%
# 테스트 데이터 정확도: 0.268%
# 테스트 데이터 정확도: 0.271%
# 테스트 데이터 정확도: 0.274%
# 테스트 데이터 정확도: 0.277%
# 테스트 데이터 정확도: 0.280%
# 테스트 데이터 정확도: 0.283%
# 테스트 데이터 정확도: 0.286%
# 테스트 데이터 정확도: 0.290%
# 테스트 데이터 정확도: 0.293%
# 테스트 데이터 정확도: 0.296%
# 테스트 데이터 정확도: 0.299%
# 테스트 데이터 정확도: 0.302%
# 테스트 데이터 정확도: 0.305%
# 테스트 데이터 정확도: 0.308%
# 테스트 데이터 정확도: 0.311%
# 테스트 데이터 정확도: 0.314%
# 테스트 데이터 정확도: 0.317%
# 테스트 데이터 정확도: 0.320%
# 테스트 데이터 정확도: 0.323%
# 테스트 데이터 정확도: 0.326%
# 테스트 데이터 정확도: 0.329%
# 테스트 데이터 정확도: 0.332%
# 테스트 데이터 정확도: 0.335%
# 테스트 데이터 정확도: 0.339%
# 테스트 데이터 정확도: 0.342%
# 테스트 데이터 정확도: 0.345%
# 테스트 데이터 정확도: 0.348%
# 테스트 데이터 정확도: 0.351%
# 테스트 데이터 정확도: 0.354%
# 테스트 데이터 정확도: 0.357%
# 테스트 데이터 정확도: 0.361%
# 테스트 데이터 정확도: 0.364%
# 테스트 데이터 정확도: 0.367%
# 테스트 데이터 정확도: 0.370%
# 테스트 데이터 정확도: 0.373%
# 테스트 데이터 정확도: 0.376%
# 테스트 데이터 정확도: 0.379%
# 테스트 데이터 정확도: 0.382%
# 테스트 데이터 정확도: 0.385%
# 테스트 데이터 정확도: 0.388%
# 테스트 데이터 정확도: 0.391%
# 테스트 데이터 정확도: 0.395%
# 테스트 데이터 정확도: 0.398%
# 테스트 데이터 정확도: 0.401%
# 테스트 데이터 정확도: 0.404%
# 테스트 데이터 정확도: 0.407%
# 테스트 데이터 정확도: 0.410%
# 테스트 데이터 정확도: 0.413%
# 테스트 데이터 정확도: 0.416%
# 테스트 데이터 정확도: 0.420%
# 테스트 데이터 정확도: 0.423%
# 테스트 데이터 정확도: 0.426%
# 테스트 데이터 정확도: 0.429%
# 테스트 데이터 정확도: 0.432%
# 테스트 데이터 정확도: 0.435%
# 테스트 데이터 정확도: 0.438%
# 테스트 데이터 정확도: 0.441%
# 테스트 데이터 정확도: 0.444%
# 테스트 데이터 정확도: 0.447%
# 테스트 데이터 정확도: 0.450%
# 테스트 데이터 정확도: 0.453%
# 테스트 데이터 정확도: 0.456%
# 테스트 데이터 정확도: 0.460%
# 테스트 데이터 정확도: 0.463%
# 테스트 데이터 정확도: 0.466%
# 테스트 데이터 정확도: 0.469%
# 테스트 데이터 정확도: 0.472%
# 테스트 데이터 정확도: 0.475%
# 테스트 데이터 정확도: 0.478%
# 테스트 데이터 정확도: 0.481%
# 테스트 데이터 정확도: 0.484%
# 테스트 데이터 정확도: 0.487%
# 테스트 데이터 정확도: 0.491%
# 테스트 데이터 정확도: 0.494%
# 테스트 데이터 정확도: 0.497%
# 테스트 데이터 정확도: 0.500%
# 테스트 데이터 정확도: 0.503%
# 테스트 데이터 정확도: 0.506%
# 테스트 데이터 정확도: 0.509%
# 테스트 데이터 정확도: 0.513%
# 테스트 데이터 정확도: 0.516%
# 테스트 데이터 정확도: 0.519%
# 테스트 데이터 정확도: 0.522%
# 테스트 데이터 정확도: 0.525%
# 테스트 데이터 정확도: 0.528%
# 테스트 데이터 정확도: 0.531%
# 테스트 데이터 정확도: 0.534%
# 테스트 데이터 정확도: 0.537%
# 테스트 데이터 정확도: 0.540%
# 테스트 데이터 정확도: 0.543%
# 테스트 데이터 정확도: 0.547%
# 테스트 데이터 정확도: 0.550%
# 테스트 데이터 정확도: 0.553%
# 테스트 데이터 정확도: 0.556%
# 테스트 데이터 정확도: 0.559%
# 테스트 데이터 정확도: 0.562%
# 테스트 데이터 정확도: 0.565%
# 테스트 데이터 정확도: 0.568%
# 테스트 데이터 정확도: 0.571%
# 테스트 데이터 정확도: 0.574%
# 테스트 데이터 정확도: 0.578%
# 테스트 데이터 정확도: 0.581%
# 테스트 데이터 정확도: 0.584%
# 테스트 데이터 정확도: 0.587%
# 테스트 데이터 정확도: 0.590%
# 테스트 데이터 정확도: 0.593%
# 테스트 데이터 정확도: 0.596%
# 테스트 데이터 정확도: 0.599%
# 테스트 데이터 정확도: 0.602%
# 테스트 데이터 정확도: 0.605%
# 테스트 데이터 정확도: 0.608%
# 테스트 데이터 정확도: 0.612%
# 테스트 데이터 정확도: 0.615%
# 테스트 데이터 정확도: 0.618%
# 테스트 데이터 정확도: 0.621%
# 테스트 데이터 정확도: 0.624%
# 테스트 데이터 정확도: 0.627%
# 테스트 데이터 정확도: 0.630%
# 테스트 데이터 정확도: 0.634%
# 테스트 데이터 정확도: 0.637%
# 테스트 데이터 정확도: 0.640%
# 테스트 데이터 정확도: 0.643%
# 테스트 데이터 정확도: 0.646%
# 테스트 데이터 정확도: 0.650%
# 테스트 데이터 정확도: 0.653%
# 테스트 데이터 정확도: 0.656%
# 테스트 데이터 정확도: 0.659%
# 테스트 데이터 정확도: 0.662%
# 테스트 데이터 정확도: 0.665%
# 테스트 데이터 정확도: 0.668%
# 테스트 데이터 정확도: 0.672%
# 테스트 데이터 정확도: 0.675%
# 테스트 데이터 정확도: 0.678%
# 테스트 데이터 정확도: 0.681%
# 테스트 데이터 정확도: 0.684%
# 테스트 데이터 정확도: 0.688%
# 테스트 데이터 정확도: 0.691%
# 테스트 데이터 정확도: 0.694%
# 테스트 데이터 정확도: 0.697%
# 테스트 데이터 정확도: 0.700%
# 테스트 데이터 정확도: 0.703%
# 테스트 데이터 정확도: 0.706%
# 테스트 데이터 정확도: 0.710%
# 테스트 데이터 정확도: 0.713%
# 테스트 데이터 정확도: 0.716%
# 테스트 데이터 정확도: 0.719%
# 테스트 데이터 정확도: 0.721%
# 테스트 데이터 정확도: 0.725%
# 테스트 데이터 정확도: 0.728%
# 테스트 데이터 정확도: 0.731%
# 테스트 데이터 정확도: 0.734%
# 테스트 데이터 정확도: 0.737%
# 테스트 데이터 정확도: 0.740%
# 테스트 데이터 정확도: 0.743%
# 테스트 데이터 정확도: 0.746%
# 테스트 데이터 정확도: 0.749%
# 테스트 데이터 정확도: 0.752%
# 테스트 데이터 정확도: 0.755%
# 테스트 데이터 정확도: 0.759%
# 테스트 데이터 정확도: 0.762%
# 테스트 데이터 정확도: 0.765%
# 테스트 데이터 정확도: 0.768%
# 테스트 데이터 정확도: 0.771%
# 테스트 데이터 정확도: 0.774%
# 테스트 데이터 정확도: 0.777%
# 테스트 데이터 정확도: 0.781%
# 테스트 데이터 정확도: 0.784%
# 테스트 데이터 정확도: 0.787%
# 테스트 데이터 정확도: 0.790%
# 테스트 데이터 정확도: 0.793%
# 테스트 데이터 정확도: 0.796%
# 테스트 데이터 정확도: 0.799%
# 테스트 데이터 정확도: 0.802%
# 테스트 데이터 정확도: 0.805%
# 테스트 데이터 정확도: 0.809%
# 테스트 데이터 정확도: 0.812%
# 테스트 데이터 정확도: 0.815%
# 테스트 데이터 정확도: 0.818%
# 테스트 데이터 정확도: 0.821%
# 테스트 데이터 정확도: 0.824%
# 테스트 데이터 정확도: 0.827%
# 테스트 데이터 정확도: 0.830%
# 테스트 데이터 정확도: 0.833%
# 테스트 데이터 정확도: 0.836%
# 테스트 데이터 정확도: 0.839%
# 테스트 데이터 정확도: 0.843%
# 테스트 데이터 정확도: 0.846%
# 테스트 데이터 정확도: 0.849%
# 테스트 데이터 정확도: 0.852%
# 테스트 데이터 정확도: 0.855%
# 테스트 데이터 정확도: 0.858%
# 테스트 데이터 정확도: 0.861%
# 테스트 데이터 정확도: 0.864%
# 테스트 데이터 정확도: 0.867%
# 테스트 데이터 정확도: 0.870%
# 테스트 데이터 정확도: 0.873%
# 테스트 데이터 정확도: 0.876%
# 테스트 데이터 정확도: 0.879%
# 테스트 데이터 정확도: 0.882%
# 테스트 데이터 정확도: 0.885%
# 테스트 데이터 정확도: 0.888%
# 테스트 데이터 정확도: 0.891%
# 테스트 데이터 정확도: 0.894%
# 테스트 데이터 정확도: 0.897%
# 테스트 데이터 정확도: 0.900%
# 테스트 데이터 정확도: 0.904%
# 테스트 데이터 정확도: 0.907%
# 테스트 데이터 정확도: 0.910%
# 테스트 데이터 정확도: 0.913%
# 테스트 데이터 정확도: 0.916%
# 테스트 데이터 정확도: 0.919%
# 테스트 데이터 정확도: 0.922%
# 테스트 데이터 정확도: 0.925%
# 테스트 데이터 정확도: 0.928%
# 테스트 데이터 정확도: 0.932%
# 테스트 데이터 정확도: 0.935%
# 테스트 데이터 정확도: 0.938%
# 테스트 데이터 정확도: 0.941%
# 테스트 데이터 정확도: 0.944%
# 테스트 데이터 정확도: 0.947%
# 테스트 데이터 정확도: 0.950%
# 테스트 데이터 정확도: 0.953%
# 테스트 데이터 정확도: 0.956%
# 테스트 데이터 정확도: 0.959%
# 테스트 데이터 정확도: 0.962%
# 테스트 데이터 정확도: 0.965%
# 테스트 데이터 정확도: 0.968%
# 테스트 데이터 정확도: 0.970%
# 10 번째 학습데이터의 테스트 결과 : tensor([[-1.1209e+01, -1.9368e-03, -8.1447e+00, -1.0620e+01, -8.5013e+00,
#          -9.7098e+00, -9.7665e+00, -7.2406e+00, -7.9287e+00, -8.4765e+00]],
#        grad_fn=<LogSoftmaxBackward0>)
# 10번째 데이터의 예측 [1]
# 실제 레이블 : 1
